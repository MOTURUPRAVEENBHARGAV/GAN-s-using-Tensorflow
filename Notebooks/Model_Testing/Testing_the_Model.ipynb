# %%
import tensorflow as tf

# %% [markdown]
# ### 200 epochs Model

# %%
MODEL_GEN = tf.saved_model.load("/content/drive/MyDrive/GAN's/Trial3/Generated_200")

# %%
# Generate new images
import matplotlib.pyplot as plt
noise = tf.random.normal([16, 100])
generated_images = MODEL_GEN(noise, training=False)
generated_images = (generated_images * 127.5) + 127.5
for i in range(generated_images.shape[0]):
    plt.subplot(4, 4, i+1)
    plt.imshow(generated_images[i].numpy().astype('int'))
    plt.axis('off')
plt.show()

# %%
# Generate new images
import matplotlib.pyplot as plt
noise = tf.random.normal([1, 100])
generated_images = MODEL_GEN(noise, training=False)
generated_images = (generated_images * 127.5) + 127.5
for i in range(generated_images.shape[0]):
    plt.subplot(4, 4, i+1)
    plt.imshow(generated_images[i].numpy().astype('int'))
    plt.axis('off')
plt.show()

# %%
GEN=tf.keras.models.load_model("/content/drive/MyDrive/GAN's/Trial3/generator_kaggle_200.h5")
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %% [markdown]
# ### 500 epochs Model

# %%
#Different Architecture with flattening the images

# %%
MODEL_GEN_2 = tf.saved_model.load("/content/drive/MyDrive/GAN's/Trial 2/generator")

# %%
# Generate new images
import matplotlib.pyplot as plt
noise = tf.random.normal([16, 100])
generated_images = MODEL_GEN_2(noise, training=False)
generated_images = (generated_images * 127.5) + 127.5
for i in range(generated_images.shape[0]):
    plt.subplot(4, 4, i+1)
    plt.imshow(generated_images[i].numpy().astype('int').reshape(32,32,3))
    plt.axis('off')
plt.show()

# %% [markdown]
# ## 1000 epochs Model

# %%
MODEL_GEN_3 = tf.saved_model.load("/content/drive/MyDrive/GAN's/Trial4/Generated 1000")

# %%
# Generate new images
import matplotlib.pyplot as plt
noise = tf.random.normal([16, 100])
generated_images = MODEL_GEN_3(noise, training=False)
generated_images = (generated_images * 127.5) + 127.5
for i in range(generated_images.shape[0]):
    plt.subplot(4, 4, i+1)
    plt.imshow(generated_images[i].numpy().astype('int'))
    plt.axis('off')
plt.show()

# %%
# Generate new images
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
noise = tf.random.normal([8, 100])
generated_images = MODEL_GEN_3(noise, training=False)
generated_images = (generated_images * 127.5) + 127.5
for i in range(generated_images.shape[0]):
    plt.subplot(4, 4, i+1)
    plt.imshow(generated_images[i].numpy().astype('int').reshape(32,32,3))
    plt.axis('off')
plt.show()
